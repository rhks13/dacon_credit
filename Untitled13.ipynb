# %%
import pandas as pd

# %%
train = pd.read.csv("C:\Users\82106\Desktop\2022\데이콘\train.csv")
# Out:
#   File "C:\Users\82106\AppData\Local\Temp/ipykernel_13868/3351929067.py", line 1
#     train = pd.read.csv("C:\Users\82106\Desktop\2022\데이콘\train.csv")
#                                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
